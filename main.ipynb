# %% [markdown]
# ### 1. Data Collecting

# %% [markdown]
# Tahapan ini ada pada `scraping.ipynb` yang dimana kita mengambil dataset sejumlah 12.000 review dari google play store menggunakan `google-play-scraper`

# %% [markdown]
# ### 2. Data Preprocessing

# %% [markdown]
# #### a. Data Info

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv('./dataset/reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reviewId  12000 non-null  object
#  1   userName  12000 non-null  object
#  2   content   12000 non-null  object
#  3   score     12000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 375.1+ KB

# %% [markdown]
# #### b. Data Sentiment
#
# Di kita akan menambahkan kolom baru pada DataFrame yaitu `sentiments` untuk membagi kelompok dari review. 0 untuk `score <= 2` dan 1 untuk `score >= 3`

# %%
df['sentiments'] = df.score.apply(lambda x: 0 if x in [1, 2] else 1)

# %% [markdown]
# ### 3. Data Analysis and Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Visualisasi terhadapat sentiment

# %%
plt.figure(figsize=(15,7))
# sentimen = df.dropna(subset=['sentiments']).sort_values(by=['sentiments'])['sentiments'].unique()
total = df.groupby(['sentiments'])['score'].count()
plt.pie(total, labels=(["Negatif", "Positif"]), autopct='%.1f%%', startangle = 120, shadow = True)
plt.title('Sentimen Game')
plt.show()

# %%
plt.figure(figsize=(15,7))
rating = df.dropna(subset=['score']).sort_values(by=['score'])['score'].unique()
total = df.groupby(['score'])['reviewId'].count()
plt.pie(total, labels=rating, autopct='%.1f%%', startangle = 120, shadow = True)
plt.title('Rating Game')
plt.show()

# %%
score= df.dropna(subset=['score']).sort_values(by=['score'])['score'].unique()
total = df.groupby(['score'])['reviewId'].count()
plt.plot(score, total, color='red')
# plt.title('')
plt.xlabel('Rating', fontsize=11)
plt.ylabel('Total Pengguna Game', fontsize=11)
plt.grid()
plt.show()

# %% [markdown]
# ### 4. Data Modeling

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tokenizer = Tokenizer(oov_token="<OOV>")

# %%
x_train, x_test, y_train, y_test = train_test_split(df['content'], df['sentiments'], test_size=0.4)

# %%
import numpy as np
training_sentences = []
training_labels = []
testing_sentences = []
testing_labels = []
for row in x_train:
    training_sentences.append(str(row))
for row in y_train:
    training_labels.append(row)
for row in x_test:
    testing_sentences.append(str(row))
for row in y_test:
    testing_labels.append(row)

# %%
vocab_size = 40000
embedding_dim = 16
max_length = 120
trunc_type = 'post'
oov_tok = '<OOV>'
padding_type = 'post'

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

word_index
# Out:
# {'<OOV>': 1,
#  'game': 2,
#  'bagus': 3,
#  'nya': 4,
#  'di': 5,
#  'saya': 6,
#  'ini': 7,
#  'dan': 8,
#  'yang': 9,
#  'bisa': 10,
#  'tapi': 11,
#  'sangat': 12,
#  'untuk': 13,
#  'seru': 14,
#  'banget': 15,
#  'main': 16,
#  'tolong': 17,
#  'yg': 18,
#  'hp': 19,
#  'aku': 20,
#  'tidak': 21,
#  'ada': 22,
#  'keren': 23,
#  'genshin': 24,
#  'buat': 25,
#  'gamenya': 26,
#  'lagi': 27,
#  'the': 28,
#  'dari': 29,
#  'grafik': 30,
#  'update': 31,
#  'gak': 32,
#  'banyak': 33,
#  'juga': 34,
#  'kasih': 35,
#  'good': 36,
#  'aja': 37,
#  'download': 38,
#  'i': 39,
#  'jadi': 40,
#  'ga': 41,
#  'udah': 42,
#  'ya': 43,
#  'suka': 44,
#  'gw': 45,
#  'gacha': 46,
#  'karakter': 47,
#  'bintang': 48,
#  'mantap': 49,
#  'sih': 50,
#  'sama': 51,
#  'sudah': 52,
#  '1': 53,
#  'itu': 54,
#  'mau': 55,
#  'lebih': 56,
#  'kalo': 57,
#  'lama': 58,
#  'karena': 59,
#  'lah': 60,
#  'impact': 61,
#  'masih': 62,
#  'dengan': 63,
#  'hoyoverse': 64,
#  'padahal': 65,
#  '5': 66,
#  'sekali': 67,
#  'data': 68,
#  '3': 69,
#  'story': 70,
#  'ke': 71,
#  'terlalu': 72,
#  'nice': 73,
#  'menarik': 74,
#  'gk': 75,
#  'baru': 76,
#  'this': 77,
#  'ku': 78,
#  'and': 79,
#  '2': 80,
#  'cuma': 81,
#  'mihoyo': 82,
#  'kalau': 83,
#  'kenapa': 84,
#  'rate': 85,
#  'harus': 86,
#  'bikin': 87,
#  'akun': 88,
#  'player': 89,
#  'terus': 90,
#  'is': 91,
#  'best': 92,
#  'semoga': 93,
#  'susah': 94,
#  'pas': 95,
#  'quest': 96,
#  'dah': 97,
#  'saat': 98,
#  'jangan': 99,
#  'to': 100,
#  'gb': 101,
#  'dong': 102,
#  'bug': 103,
#  'pity': 104,
#  'semua': 105,
#  'dapet': 106,
#  'event': 107,
#  'for': 108,
#  'dapat': 109,
#  'cerita': 110,
#  'it': 111,
#  'kok': 112,
#  'udh': 113,
#  'apa': 114,
#  'ok': 115,
#  'you': 116,
#  'fitur': 117,
#  'artefak': 118,
#  'berat': 119,
#  'atau': 120,
#  'in': 121,
#  'perbaiki': 122,
#  'terbaik': 123,
#  'bermain': 124,
#  'please': 125,
#  'ram': 126,
#  'mohon': 127,
#  'kali': 128,
#  'segi': 129,
#  'pernah': 130,
#  'gua': 131,
#  'gg': 132,
#  'seperti': 133,
#  'lumayan': 134,
#  'kurang': 135,
#  'biar': 136,
#  'sering': 137,
#  'masuk': 138,
#  'gameplay': 139,
#  'pelit': 140,
#  'lag': 141,
#  'selalu': 142,
#  'dalam': 143,
#  'ampas': 144,
#  'besar': 145,
#  'lain': 146,
#  'my': 147,
#  'karna': 148,
#  'ni': 149,
#  'hanya': 150,
#  'makin': 151,
#  'a': 152,
#  'sekarang': 153,
#  'saja': 154,
#  'cuman': 155,
#  'malah': 156,
#  'kentang': 157,
#  'hadiah': 158,
#  'up': 159,
#  'ny': 160,
#  'grafiknya': 161,
#  'sumeru': 162,
#  'dulu': 163,
#  'so': 164,
#  'kalian': 165,
#  'but': 166,
#  'bgt': 167,
#  'waktu': 168,
#  'orang': 169,
#  'agak': 170,
#  'alur': 171,
#  'login': 172,
#  'membuat': 173,
#  'gem': 174,
#  'primo': 175,
#  'b5': 176,
#  'device': 177,
#  'like': 178,
#  'of': 179,
#  'me': 180,
#  'gitu': 181,
#  'penyimpanan': 182,
#  'map': 183,
#  'terimakasih': 184,
#  'sampai': 185,
#  'akan': 186,
#  'mulu': 187,
#  'paling': 188,
#  'give': 189,
#  'hd': 190,
#  'cukup': 191,
#  'agar': 192,
#  'resin': 193,
#  'mungkin': 194,
#  'anniversary': 195,
#  'off': 196,
#  'parah': 197,
#  'mobile': 198,
#  'baik': 199,
#  'very': 200,
#  'min': 201,
#  'developer': 202,
#  '👍': 203,
#  '4': 204,
#  'love': 205,
#  'android': 206,
#  'kan': 207,
#  'satu': 208,
#  'top': 209,
#  'kita': 210,
#  'sampe': 211,
#  'setelah': 212,
#  'size': 213,
#  'tahun': 214,
#  'nih': 215,
#  'no': 216,
#  'pengen': 217,
#  'menyenangkan': 218,
#  'walaupun': 219,
#  'pokoknya': 220,
#  'kecewa': 221,
#  'lancar': 222,
#  'open': 223,
#  'belum': 224,
#  'saran': 225,
#  'jelek': 226,
#  'sistem': 227,
#  'pada': 228,
#  'hari': 229,
#  'sedikit': 230,
#  'setiap': 231,
#  'nahida': 232,
#  'soalnya': 233,
#  'masalah': 234,
#  'play': 235,
#  'memori': 236,
#  'hapus': 237,
#  'awal': 238,
#  'character': 239,
#  'pun': 240,
#  'doang': 241,
#  'patah': 242,
#  'world': 243,
#  'sendiri': 244,
#  'masa': 245,
#  'wibu': 246,
#  'kuat': 247,
#  'misi': 248,
#  'tau': 249,
#  'more': 250,
#  'kayak': 251,
#  'tpi': 252,
#  'on': 253,
#  '10': 254,
#  'diperbaiki': 255,
#  'semakin': 256,
#  'para': 257,
#  'make': 258,
#  'ceritanya': 259,
#  'oke': 260,
#  'coba': 261,
#  'mb': 262,
#  'sulit': 263,
#  'punya': 264,
#  'f2p': 265,
#  'g': 266,
#  'sy': 267,
#  'kadang': 268,
#  'rpg': 269,
#  'nggak': 270,
#  'menjadi': 271,
#  'dpt': 272,
#  'kaya': 273,
#  'klo': 274,
#  'that': 275,
#  'keluar': 276,
#  'tambahin': 277,
#  'bener': 278,
#  'gue': 279,
#  'loading': 280,
#  'deh': 281,
#  'si': 282,
#  '0': 283,
#  'ingin': 284,
#  'versi': 285,
#  'pake': 286,
#  'jaringan': 287,
#  'd': 288,
#  'reward': 289,
#  'tetap': 290,
#  'can': 291,
#  'terima': 292,
#  'kek': 293,
#  'tambah': 294,
#  'bagi': 295,
#  'have': 296,
#  '50': 297,
#  'apalagi': 298,
#  'maen': 299,
#  'support': 300,
#  'pasti': 301,
#  'wangy': 302,
#  'hard': 303,
#  'mulai': 304,
#  'ngelag': 305,
#  'adalah': 306,
#  'fix': 307,
#  'mainkan': 308,
#  'beberapa': 309,
#  'ulang': 310,
#  'mana': 311,
#  'ping': 312,
#  'makasih': 313,
#  'overall': 314,
#  'pc': 315,
#  'walau': 316,
#  'bet': 317,
#  'rating': 318,
#  'pihak': 319,
#  'not': 320,
#  'banner': 321,
#  'kasi': 322,
#  'hal': 323,
#  'drop': 324,
#  'ukuran': 325,
#  'maaf': 326,
#  'cocok': 327,
#  'kalah': 328,
#  'sayang': 329,
#  'mendapatkan': 330,
#  'bukan': 331,
#  'asik': 332,
#  'domain': 333,
#  'gimana': 334,
#  'anime': 335,
#  'langsung': 336,
#  'supaya': 337,
#  'senjata': 338,
#  'server': 339,
#  'baguss': 340,
#  'ramah': 341,
#  'enak': 342,
#  'just': 343,
#  'beri': 344,
#  'with': 345,
#  'dll': 346,
#  'pemain': 347,
#  'cepat': 348,
#  'hilang': 349,
#  'mainin': 350,
#  'char': 351,
#  'bosen': 352,
#  'skip': 353,
#  'biasa': 354,
#  'yah': 355,
#  'sinyal': 356,
#  'penuh': 357,
#  'tp': 358,
#  '4no': 359,
#  'gede': 360,
#  'close': 361,
#  'primogem': 362,
#  'storynya': 363,
#  'mudah': 364,
#  'tiba': 365,
#  'anda': 366,
#  'semuanya': 367,
#  'sumpah': 368,
#  'cuy': 369,
#  'ama': 370,
#  'musuh': 371,
#  'datanya': 372,
#  'lu': 373,
#  'zhongli': 374,
#  'force': 375,
#  'bosan': 376,
#  'ar': 377,
#  'geme': 378,
#  'tetep': 379,
#  'menurut': 380,
#  'mantep': 381,
#  'pls': 382,
#  'farming': 383,
#  'tambahkan': 384,
#  'star': 385,
#  'be': 386,
#  'gara': 387,
#  'pertama': 388,
#  'luar': 389,
#  'ever': 390,
#  'an': 391,
#  'happy': 392,
#  'abis': 393,
#  'v': 394,
#  'nanti': 395,
#  'dunia': 396,
#  'mending': 397,
#  'grafis': 398,
#  'pensi': 399,
#  'storage': 400,
#  'butuh': 401,
#  'frame': 402,
#  '🗿': 403,
#  'menang': 404,
#  'full': 405,
#  'tinggi': 406,
#  'cara': 407,
#  'minta': 408,
#  'thanks': 409,
#  '8': 410,
#  'jika': 411,
#  'emang': 412,
#  'hoyovers': 413,
#  'will': 414,
#  'because': 415,
#  'permainan': 416,
#  'really': 417,
#  'hoki': 418,
#  'petualangan': 419,
#  'males': 420,
#  'thank': 421,
#  'are': 422,
#  'jg': 423,
#  'perlu': 424,
#  'jalan': 425,
#  'pakai': 426,
#  'dikit': 427,
#  'qiqi': 428,
#  'namun': 429,
#  "it's": 430,
#  'hampir': 431,
#  'even': 432,
#  'semangat': 433,
#  'wajib': 434,
#  'amat': 435,
#  'terbaru': 436,
#  'why': 437,
#  'wifi': 438,
#  'end': 439,
#  'nyaman': 440,
#  'aplikasi': 441,
#  'selesai': 442,
#  'panas': 443,
#  'lawan': 444,
#  'habis': 445,
#  'nunggu': 446,
#  'fps': 447,
#  'if': 448,
#  'or': 449,
#  'archon': 450,
#  'tetapi': 451,
#  'ngasih': 452,
#  'atas': 453,
#  'gratis': 454,
#  'nilou': 455,
#  'berikan': 456,
#  'gim': 457,
#  'mata': 458,
#  'burik': 459,
#  'karakternya': 460,
#  'rata': 461,
#  'waifu': 462,
#  'bang': 463,
#  'spiral': 464,
#  'low': 465,
#  'memuaskan': 466,
#  'kembali': 467,
#  'its': 468,
#  'kata': 469,
#  'liat': 470,
#  'mainnya': 471,
#  'memainkan': 472,
#  'dimainkan': 473,
#  'kedepannya': 474,
#  'bgus': 475,
#  'hehe': 476,
#  'lite': 477,
#  'nge': 478,
#  'harap': 479,
#  'minimal': 480,
#  'konten': 481,
#  'as': 482,
#  'puzzle': 483,
#  'account': 484,
#  "don't": 485,
#  'sampah': 486,
#  'apakah': 487,
#  'merah': 488,
#  'santai': 489,
#  'berharap': 490,
#  'ganti': 491,
#  'gachanya': 492,
#  '100': 493,
#  'gila': 494,
#  'patch': 495,
#  'sebelumnya': 496,
#  'free': 497,
#  'mengecewakan': 498,
#  'bgs': 499,
#  'primogems': 500,
#  'desain': 501,
#  'error': 502,
#  '20': 503,
#  'damage': 504,
#  'one': 505,
#  'semenjak': 506,
#  'telah': 507,
#  'controller': 508,
#  'spek': 509,
#  'monster': 510,
#  'buruk': 511,
#  'ketika': 512,
#  'muncul': 513,
#  'dikasih': 514,
#  'ganyu': 515,
#  'anj': 516,
#  "i'm": 517,
#  'dri': 518,
#  'kazuha': 519,
#  'luas': 520,
#  'gini': 521,
#  'aj': 522,
#  'bulan': 523,
#  'banyakin': 524,
#  'sebagai': 525,
#  'begitu': 526,
#  'memory': 527,
#  'jelas': 528,
#  'capek': 529,
#  'kekurangan': 530,
#  'we': 531,
#  'all': 532,
#  'kepada': 533,
#  'there': 534,
#  'nyari': 535,
#  'level': 536,
#  'weapon': 537,
#  'raiden': 538,
#  'venti': 539,
#  'hack': 540,
#  'rendah': 541,
#  'melihat': 542,
#  'rilis': 543,
#  'wow': 544,
#  'membosankan': 545,
#  'beli': 546,
#  'seruu': 547,
#  'always': 548,
#  'memberikan': 549,
#  'ditambah': 550,
#  'kami': 551,
#  'akhirnya': 552,
#  'want': 553,
#  '200': 554,
#  'segera': 555,
#  'fun': 556,
#  'boleh': 557,
#  'soal': 558,
#  'memiliki': 559,
#  'memanjakan': 560,
#  'get': 561,
#  'lalu': 562,
#  'terjadi': 563,
#  'hu': 564,
#  'teki': 565,
#  'amazing': 566,
#  'bilang': 567,
#  'secara': 568,
#  'next': 569,
#  'salah': 570,
#  'sekian': 571,
#  'benar': 572,
#  'perfect': 573,
#  'too': 574,
#  'still': 575,
#  'aman': 576,
#  'tiap': 577,
#  'meledak': 578,
#  'sya': 579,
#  'naik': 580,
#  'bansos': 581,
#  'jam': 582,
#  'chara': 583,
#  'kecil': 584,
#  'tuh': 585,
#  'fantasy': 586,
#  'plis': 587,
#  'ruang': 588,
#  'mendukung': 589,
#  'moga': 590,
#  'eror': 591,
#  'adventure': 592,
#  'lo': 593,
#  "can't": 594,
#  'teka': 595,
#  'cmn': 596,
#  'great': 597,
#  'boss': 598,
#  'teman': 599,
#  '🥰': 600,
#  'nyesel': 601,
#  'gabisa': 602,
#  'mmorpg': 603,
#  'forno': 604,
#  'games': 605,
#  'ternyata': 606,
#  'lima': 607,
#  'memang': 608,
#  'suruh': 609,
#  'tombol': 610,
#  'trs': 611,
#  'jauh': 612,
#  'pengguna': 613,
#  'oh': 614,
#  'win': 615,
#  'your': 616,
#  'katanya': 617,
#  'pull': 618,
#  'permudah': 619,
#  'memakan': 620,
#  'bnyk': 621,
#  'kena': 622,
#  '2nd': 623,
#  'indah': 624,
#  'lg': 625,
#  'updatenya': 626,
#  'cool': 627,
#  'dev': 628,
#  'tao': 629,
#  'ngga': 630,
#  'eh': 631,
#  'keqing': 632,
#  'jgn': 633,
#  'musik': 634,
#  'makan': 635,
#  '6': 636,
#  'yaitu': 637,
#  't': 638,
#  'much': 639,
#  'ngotak': 640,
#  'kebanyakan': 641,
#  'jdi': 642,
#  'ajg': 643,
#  'apk': 644,
#  'kurangi': 645,
#  '30': 646,
#  'sayangnya': 647,
#  'job': 648,
#  'delay': 649,
#  'ringan': 650,
#  'pengalaman': 651,
#  'puas': 652,
#  'arte': 653,
#  'def': 654,
#  'internal': 655,
#  'bismillah': 656,
#  'tunggu': 657,
#  'senang': 658,
#  'selanjutnya': 659,
#  'aneh': 660,
#  'bakal': 661,
#  'menunggu': 662,
#  'sesuai': 663,
#  'mayan': 664,
#  'hope': 665,
#  'knp': 666,
#  'animasi': 667,
#  'anniv': 668,
#  'lainnya': 669,
#  'pemula': 670,
#  'aniv': 671,
#  'bad': 672,
#  'only': 673,
#  'akhir': 674,
#  'b': 675,
#  'babi': 676,
#  'tersebut': 677,
#  'bngt': 678,
#  'phone': 679,
#  'stabil': 680,
#  'render': 681,
#  'kamu': 682,
#  'wkwk': 683,
#  'ko': 684,
#  'buka': 685,
#  'ah': 686,
#  'lupa': 687,
#  'perbanyak': 688,
#  'ayaka': 689,
#  'dh': 690,
#  'oleh': 691,
#  'u': 692,
#  'skill': 693,
#  'kuota': 694,
#  'trus': 695,
#  'abyss': 696,
#  'paimon': 697,
#  'yaa': 698,
#  'wish': 699,
#  'mode': 700,
#  "story'": 701,
#  'need': 702,
#  'sini': 703,
#  'temen': 704,
#  'again': 705,
#  'sukses': 706,
#  'sedang': 707,
#  'loh': 708,
#  'handphone': 709,
#  '😁': 710,
#  'suara': 711,
#  'sebelum': 712,
#  'terutama': 713,
#  'indonesia': 714,
#  'lgi': 715,
#  'org': 716,
#  'pliss': 717,
#  'gi': 718,
#  'merasakan': 719,
#  'bangett': 720,
#  'gaming': 721,
#  '9': 722,
#  'nerf': 723,
#  'gamepad': 724,
#  'tinggal': 725,
#  'better': 726,
#  'add': 727,
#  'dear': 728,
#  'op': 729,
#  'from': 730,
#  'inazuma': 731,
#  'rng': 732,
#  'us': 733,
#  'tak': 734,
#  'enjoy': 735,
#  'selama': 736,
#  'kapan': 737,
#  '14': 738,
#  'hitam': 739,
#  'meskipun': 740,
#  'naikin': 741,
#  'now': 742,
#  'hero': 743,
#  'pokok': 744,
#  'selain': 745,
#  '16': 746,
#  'tingkatkan': 747,
#  '\u2060': 748,
#  'asu': 749,
#  'ngeframe': 750,
#  'rerun': 751,
#  'jujur': 752,
#  '🥲': 753,
#  'tower': 754,
#  '😭': 755,
#  'perangkat': 756,
#  'playing': 757,
#  '70': 758,
#  'btw': 759,
#  'hati': 760,
#  'sia': 761,
#  'boring': 762,
#  'do': 763,
#  'hoyo': 764,
#  'version': 765,
#  'pusing': 766,
#  'tdk': 767,
#  'bahkan': 768,
#  'optimalkan': 769,
#  'dialog': 770,
#  'after': 771,
#  'berkembang': 772,
#  'honkai': 773,
#  'memukau': 774,
#  'mabar': 775,
#  'menengah': 776,
#  'tentang': 777,
#  'new': 778,
#  'hape': 779,
#  'cyno': 780,
#  'enggak': 781,
#  'snapdragon': 782,
#  'memo': 783,
#  'berapa': 784,
#  'material': 785,
#  'cepet': 786,
#  'tanpa': 787,
#  'ngak': 788,
#  'time': 789,
#  'koneksi': 790,
#  'stat': 791,
#  'ukurannya': 792,
#  'layar': 793,
#  'kedepan': 794,
#  'mati': 795,
#  'ad': 796,
#  'balik': 797,
#  'yoimiya': 798,
#  'upgrade': 799,
#  'percakapan': 800,
#  'pemandangan': 801,
#  'smartphone': 802,
#  'keseluruhan': 803,
#  '90': 804,
#  'intinya': 805,
#  'klee': 806,
#  'kecuali': 807,
#  'item': 808,
#  'sejak': 809,
#  '8gb': 810,
#  '🙂': 811,
#  'mereka': 812,
#  'at': 813,
#  'soft': 814,
#  'sedih': 815,
#  'elit': 816,
#  'benerin': 817,
#  '60': 818,
#  'bingung': 819,
#  'kurangin': 820,
#  'keep': 821,
#  'dimainin': 822,
#  'selamat': 823,
#  'pokonya': 824,
#  'jd': 825,
#  'cari': 826,
#  'berpetualang': 827,
#  'also': 828,
#  '2022': 829,
#  'rame': 830,
#  'kontol': 831,
#  'pulang': 832,
#  'sehingga': 833,
#  'menggunakan': 834,
#  'endgame': 835,
#  'rusak': 836,
#  'gampang': 837,
#  'elemental': 838,
#  'penting': 839,
#  'pula': 840,
#  'mendownload': 841,
#  'kokomi': 842,
#  'entah': 843,
#  'dlu': 844,
#  'otak': 845,
#  'duit': 846,
#  'panjang': 847,
#  'kuning': 848,
#  'co': 849,
#  'spesifikasi': 850,
#  'menikmati': 851,
#  'berbagai': 852,
#  'dikurangi': 853,
#  'asia': 854,
#  'pay': 855,
#  'sekitar': 856,
#  '7': 857,
#  'artifact': 858,
#  'crit': 859,
#  'ngabisin': 860,
#  'xiao': 861,
#  'kelamaan': 862,
#  'beda': 863,
#  'tu': 864,
#  'berhenti': 865,
#  '80': 866,
#  'chipset': 867,
#  'unik': 868,
#  'battle': 869,
#  'some': 870,
#  '👍👍👍': 871,
#  'graphic': 872,
#  'bawah': 873,
#  'merasa': 874,
#  'woy': 875,
#  '11': 876,
#  'when': 877,
#  'traveler': 878,
#  'kode': 879,
#  'kemarin': 880,
#  'ak': 881,
#  "'": 882,
#  'graphics': 883,
#  'penasaran': 884,
#  'jadinya': 885,
#  'gpp': 886,
#  'mengalami': 887,
#  '64': 888,
#  'sm': 889,
#  'jumlah': 890,
#  'aniversary': 891,
#  'tolonglah': 892,
#  'alhamdulillah': 893,
#  '🙏': 894,
#  'google': 895,
#  'turun': 896,
#  'mengunduh': 897,
#  'im': 898,
#  'uninstall': 899,
#  'malas': 900,
#  'baca': 901,
#  'menit': 902,
#  'cok': 903,
#  'hutao': 904,
#  'normal': 905,
#  'gensin': 906,
#  'mencari': 907,
#  'iya': 908,
#  'tolol': 909,
#  'sungguh': 910,
#  'come': 911,
#  'got': 912,
#  'nambah': 913,
#  'maupun': 914,
#  'lanjut': 915,
#  'storyline': 916,
#  'bersama': 917,
#  'terhadap': 918,
#  'sorry': 919,
#  'nyoba': 920,
#  'akal': 921,
#  'seneng': 922,
#  'kanan': 923,
#  'childe': 924,
#  'perkecil': 925,
#  'mona': 926,
#  'far': 927,
#  'explore': 928,
#  'kyk': 929,
#  'bakalan': 930,
#  'menghibur': 931,
#  'bagian': 932,
#  'who': 933,
#  'ketagihan': 934,
#  'youtube': 935,
#  '4gb': 936,
#  'apaan': 937,
#  'sempurna': 938,
#  '128': 939,
#  'kendala': 940,
#  'dia': 941,
#  'content': 942,
#  'hidup': 943,
#  'masalahnya': 944,
#  'terkadang': 945,
#  'mantab': 946,
#  'wah': 947,
#  'ngebosenin': 948,
#  'internet': 949,
#  'cantik': 950,
#  'eksplorasi': 951,
#  'musuhnya': 952,
#  'rasanya': 953,
#  'about': 954,
#  'file': 955,
#  'ditambahkan': 956,
#  'ghensin': 957,
#  'berada': 958,
#  'rank': 959,
#  'anak': 960,
#  'gagal': 961,
#  'dimana': 962,
#  'memberi': 963,
#  'spin': 964,
#  'makanya': 965,
#  'bugnya': 966,
#  'usah': 967,
#  'melawan': 968,
#  'diluc': 969,
#  'code': 970,
#  'y': 971,
#  'feel': 972,
#  '👎': 973,
#  'bagussss': 974,
#  'rasa': 975,
#  'tempat': 976,
#  'dipermudah': 977,
#  'well': 978,
#  'ngeleg': 979,
#  'welkin': 980,
#  'performa': 981,
#  'keamanan': 982,
#  'muat': 983,
#  'was': 984,
#  'depan': 985,
#  'edit': 986,
#  'aether': 987,
#  'harusnya': 988,
#  'wkwkwk': 989,
#  'visual': 990,
#  'instal': 991,
#  'though': 992,
#  'favorit': 993,
#  "i've": 994,
#  'been': 995,
#  '😂': 996,
#  'questnya': 997,
#  'cape': 998,
#  'kualitas': 999,
#  'sebelah': 1000,
#  ...}

# %%
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences, maxlen=max_length, truncating=trunc_type)
testing_sentences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sentences, maxlen=max_length)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim,       input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           640000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 6)                 102
#
#  dense_1 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 640,109
# Trainable params: 640,109
# Non-trainable params: 0
# _________________________________________________________________

# %%
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

testing_labels_final
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
num_epochs = 20
history = model.fit(padded, training_labels_final, batch_size=10,epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/20
# 720/720 [==============================] - 6s 7ms/step - loss: 0.4920 - accuracy: 0.8126 - val_loss: 0.4512 - val_accuracy: 0.8254
# Epoch 2/20
# 720/720 [==============================] - 5s 7ms/step - loss: 0.4633 - accuracy: 0.8149 - val_loss: 0.4454 - val_accuracy: 0.8254
# Epoch 3/20
# 720/720 [==============================] - 5s 7ms/step - loss: 0.4503 - accuracy: 0.8157 - val_loss: 0.4303 - val_accuracy: 0.8263
# Epoch 4/20
# 712/720 [============================>.] - ETA: 0s - loss: 0.4205 - accuracy: 0.8206

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs=range(len(acc))
plt.plot(epochs, acc, 'r', 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', 'Validation Accuracy')
plt.title('Training and validation accuracy')
plt.figure()
plt.plot(epochs, loss, 'r', 'Training Loss')
plt.plot(epochs, val_loss, 'b', 'Validation Loss')
plt.title('Training and validation loss')
plt.figure()

# %%
predict_sentences = tokenizer.texts_to_sequences([
"Eh Hasilnya AMPAS!!!",
"Semakin mantep Update Sumeru. Semua dari update ini saya Suka Semua dari segi Design Charnya, Viewnya, Dan juga Story nya Epic PARAAHHH",
"jelek banget",
"bagus"])
predict_padded = pad_sequences(predict_sentences, maxlen=max_length)

model.predict(predict_padded)
# Out:
# 1/1 [==============================] - 0s 140ms/step
# array([[0.49923536, 0.5026118 ],
#        [0.49932313, 0.50202876],
#        [0.49920693, 0.5025895 ],
#        [0.49920383, 0.50264883]], dtype=float32)
