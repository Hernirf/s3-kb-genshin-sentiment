# %% [markdown]
# ### 1. Data Collecting

# %% [markdown]
# Tahapan ini ada pada `scraping.ipynb` yang dimana kita mengambil dataset sejumlah 12.000 review dari google play store menggunakan `google-play-scraper`

# %% [markdown]
# ### 2. Data Preprocessing

# %% [markdown]
# #### a. Data Info

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv('./dataset/reviews.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   reviewId  12000 non-null  object
#  1   userName  12000 non-null  object
#  2   content   12000 non-null  object
#  3   score     12000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 375.1+ KB

# %% [markdown]
# #### b. Data Sentiment
#
# Di kita akan menambahkan kolom baru pada DataFrame yaitu `sentiments` untuk membagi kelompok dari review. 0 untuk `score <= 2` dan 1 untuk `score >= 3`

# %%
df['sentiments'] = df.score.apply(lambda x: 0 if x in [1, 2] else 1)

# %% [markdown]
# ### 3. Data Analysis and Visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Visualisasi terhadapat sentiment

# %%
plt.figure(figsize=(15,7))
# sentimen = df.dropna(subset=['sentiments']).sort_values(by=['sentiments'])['sentiments'].unique()
total = df.groupby(['sentiments'])['score'].count()
plt.pie(total, labels=(["Negatif", "Positif"]), autopct='%.1f%%', startangle = 120, shadow = True)
plt.title('Sentimen Game')
plt.show()

# %%
plt.figure(figsize=(15,7))
rating = df.dropna(subset=['score']).sort_values(by=['score'])['score'].unique()
total = df.groupby(['score'])['reviewId'].count()
plt.pie(total, labels=rating, autopct='%.1f%%', startangle = 120, shadow = True)
plt.title('Rating Game')
plt.show()

# %%
tahun= df.dropna(subset=['score']).sort_values(by=['score'])['score'].unique()
total = df.groupby(['score'])['reviewId'].count()
plt.plot(tahun, total, color='red')
# plt.title('')
plt.xlabel('Rating', fontsize=11)
plt.ylabel('Total Pengguna Game', fontsize=11)
plt.grid()
plt.show()

# %% [markdown]
# ### 4. Data Modeling

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tokenizer = Tokenizer(oov_token="<OOV>")

# %%
x_train, x_test, y_train, y_test = train_test_split(df['content'], df['sentiments'], test_size=0.4)

# %%
import numpy as np
training_sentences = []
training_labels = []
testing_sentences = []
testing_labels = []
for row in x_train:
    training_sentences.append(str(row))
for row in y_train:
    training_labels.append(row)
for row in x_test:
    testing_sentences.append(str(row))
for row in y_test:
    testing_labels.append(row)

# %%
vocab_size = 40000
embedding_dim = 16
max_length = 120
trunc_type = 'post'
oov_tok = '<OOV>'
padding_type = 'post'

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

word_index
# Out:
# {'<OOV>': 1,
#  'game': 2,
#  'bagus': 3,
#  'nya': 4,
#  'di': 5,
#  'saya': 6,
#  'ini': 7,
#  'dan': 8,
#  'yang': 9,
#  'bisa': 10,
#  'tapi': 11,
#  'sangat': 12,
#  'untuk': 13,
#  'banget': 14,
#  'seru': 15,
#  'hp': 16,
#  'main': 17,
#  'tolong': 18,
#  'yg': 19,
#  'tidak': 20,
#  'aku': 21,
#  'gamenya': 22,
#  'lagi': 23,
#  'ada': 24,
#  'keren': 25,
#  'genshin': 26,
#  'buat': 27,
#  'dari': 28,
#  'gak': 29,
#  'the': 30,
#  'update': 31,
#  'grafik': 32,
#  'juga': 33,
#  'banyak': 34,
#  'aja': 35,
#  'good': 36,
#  'gw': 37,
#  'kasih': 38,
#  'jadi': 39,
#  'udah': 40,
#  'download': 41,
#  'ga': 42,
#  'ya': 43,
#  'suka': 44,
#  'i': 45,
#  'karakter': 46,
#  'mantap': 47,
#  'bintang': 48,
#  'gacha': 49,
#  'itu': 50,
#  'sih': 51,
#  'sama': 52,
#  'sudah': 53,
#  'mau': 54,
#  'lebih': 55,
#  '1': 56,
#  'lah': 57,
#  'lama': 58,
#  '5': 59,
#  'kalo': 60,
#  'karena': 61,
#  'impact': 62,
#  'padahal': 63,
#  'dengan': 64,
#  'gk': 65,
#  '3': 66,
#  'data': 67,
#  'nice': 68,
#  'mihoyo': 69,
#  'terlalu': 70,
#  'story': 71,
#  'masih': 72,
#  'ke': 73,
#  'baru': 74,
#  'hoyoverse': 75,
#  'susah': 76,
#  'best': 77,
#  'ku': 78,
#  'this': 79,
#  'cuma': 80,
#  'menarik': 81,
#  'semoga': 82,
#  'pas': 83,
#  'harus': 84,
#  'player': 85,
#  'terus': 86,
#  'and': 87,
#  'dapet': 88,
#  'rate': 89,
#  'bikin': 90,
#  '2': 91,
#  'kalau': 92,
#  'to': 93,
#  'is': 94,
#  'sekali': 95,
#  'gb': 96,
#  'akun': 97,
#  'quest': 98,
#  'udh': 99,
#  'jangan': 100,
#  'kenapa': 101,
#  'pity': 102,
#  'dah': 103,
#  'artefak': 104,
#  'gua': 105,
#  'fitur': 106,
#  'dong': 107,
#  'semua': 108,
#  'kok': 109,
#  'event': 110,
#  'bug': 111,
#  'cerita': 112,
#  'dapat': 113,
#  'bermain': 114,
#  'atau': 115,
#  'for': 116,
#  'perbaiki': 117,
#  'mohon': 118,
#  'apa': 119,
#  'malah': 120,
#  'please': 121,
#  'sering': 122,
#  'saat': 123,
#  'selalu': 124,
#  'kurang': 125,
#  'lag': 126,
#  'makin': 127,
#  'in': 128,
#  'ram': 129,
#  'masuk': 130,
#  'kali': 131,
#  'karna': 132,
#  'ok': 133,
#  'gg': 134,
#  'biar': 135,
#  'sumeru': 136,
#  'pernah': 137,
#  'dalam': 138,
#  'ni': 139,
#  'sekarang': 140,
#  'hadiah': 141,
#  'it': 142,
#  'lain': 143,
#  'you': 144,
#  'berat': 145,
#  'kentang': 146,
#  'cuman': 147,
#  'besar': 148,
#  'a': 149,
#  'of': 150,
#  'hanya': 151,
#  'seperti': 152,
#  'segi': 153,
#  'paling': 154,
#  'gem': 155,
#  'terbaik': 156,
#  'pelit': 157,
#  'gameplay': 158,
#  'like': 159,
#  'bgt': 160,
#  'dulu': 161,
#  'me': 162,
#  'saja': 163,
#  'grafiknya': 164,
#  'parah': 165,
#  'ampas': 166,
#  'orang': 167,
#  'kalian': 168,
#  'waktu': 169,
#  'android': 170,
#  'membuat': 171,
#  'so': 172,
#  'baik': 173,
#  'primo': 174,
#  'mulu': 175,
#  'up': 176,
#  'my': 177,
#  'but': 178,
#  'kan': 179,
#  'agak': 180,
#  'developer': 181,
#  'terimakasih': 182,
#  'login': 183,
#  'lumayan': 184,
#  'alur': 185,
#  'size': 186,
#  'give': 187,
#  'sampai': 188,
#  'mobile': 189,
#  'masalah': 190,
#  'ny': 191,
#  'hd': 192,
#  'gitu': 193,
#  'pengen': 194,
#  '4': 195,
#  'kuat': 196,
#  'cukup': 197,
#  'tpi': 198,
#  '👍': 199,
#  'jelek': 200,
#  'lancar': 201,
#  'nahida': 202,
#  'kita': 203,
#  'map': 204,
#  'love': 205,
#  'belum': 206,
#  'agar': 207,
#  'b5': 208,
#  'nih': 209,
#  'versi': 210,
#  'min': 211,
#  'penyimpanan': 212,
#  'saran': 213,
#  'primogem': 214,
#  'sedikit': 215,
#  'kayak': 216,
#  'device': 217,
#  '0': 218,
#  'maen': 219,
#  'setelah': 220,
#  'mungkin': 221,
#  'walaupun': 222,
#  'world': 223,
#  'semakin': 224,
#  'pokoknya': 225,
#  'off': 226,
#  'misi': 227,
#  'punya': 228,
#  'tahun': 229,
#  'anniversary': 230,
#  'open': 231,
#  'loading': 232,
#  'very': 233,
#  'ping': 234,
#  'masa': 235,
#  'sampe': 236,
#  'doang': 237,
#  'klo': 238,
#  'akan': 239,
#  'top': 240,
#  'coba': 241,
#  'kecewa': 242,
#  'on': 243,
#  'satu': 244,
#  'pada': 245,
#  'memori': 246,
#  'sulit': 247,
#  'jaringan': 248,
#  'awal': 249,
#  'soalnya': 250,
#  'play': 251,
#  'setiap': 252,
#  'resin': 253,
#  'deh': 254,
#  'tetap': 255,
#  'mendapatkan': 256,
#  'pun': 257,
#  'wibu': 258,
#  'menyenangkan': 259,
#  'apalagi': 260,
#  'ngelag': 261,
#  'tambah': 262,
#  'hari': 263,
#  'keluar': 264,
#  'nggak': 265,
#  'domain': 266,
#  'kek': 267,
#  'pake': 268,
#  'sistem': 269,
#  'f2p': 270,
#  'd': 271,
#  'mb': 272,
#  '50': 273,
#  'make': 274,
#  'diperbaiki': 275,
#  'no': 276,
#  'sy': 277,
#  'bagi': 278,
#  'hapus': 279,
#  'that': 280,
#  'oke': 281,
#  '10': 282,
#  'sendiri': 283,
#  'ceritanya': 284,
#  'g': 285,
#  'banner': 286,
#  'more': 287,
#  'patah': 288,
#  'gue': 289,
#  'have': 290,
#  'kalah': 291,
#  'langsung': 292,
#  'si': 293,
#  'ama': 294,
#  'bukan': 295,
#  'supaya': 296,
#  'server': 297,
#  'gede': 298,
#  'pemain': 299,
#  'character': 300,
#  'menjadi': 301,
#  'sayang': 302,
#  'hal': 303,
#  'wangy': 304,
#  'ingin': 305,
#  'kaya': 306,
#  'tau': 307,
#  'pc': 308,
#  'tambahin': 309,
#  'terima': 310,
#  'reward': 311,
#  'ar': 312,
#  'adalah': 313,
#  'support': 314,
#  'maaf': 315,
#  'drop': 316,
#  'yah': 317,
#  'tiba': 318,
#  'sinyal': 319,
#  'senjata': 320,
#  'butuh': 321,
#  'dpt': 322,
#  'kasi': 323,
#  'biasa': 324,
#  'bosen': 325,
#  'ulang': 326,
#  'with': 327,
#  'end': 328,
#  'mainin': 329,
#  'zhongli': 330,
#  'qiqi': 331,
#  'ramah': 332,
#  'bener': 333,
#  'char': 334,
#  'skip': 335,
#  'baguss': 336,
#  'ever': 337,
#  'kadang': 338,
#  'fix': 339,
#  'dikit': 340,
#  'sumpah': 341,
#  'can': 342,
#  'lu': 343,
#  'rpg': 344,
#  'mulai': 345,
#  'ketika': 346,
#  'not': 347,
#  'mantep': 348,
#  'hard': 349,
#  'musuh': 350,
#  'para': 351,
#  'ukuran': 352,
#  'mana': 353,
#  'pls': 354,
#  'hu': 355,
#  'grafis': 356,
#  'anda': 357,
#  'walau': 358,
#  'an': 359,
#  'semangat': 360,
#  'cuy': 361,
#  'pakai': 362,
#  'tp': 363,
#  'v': 364,
#  'nyaman': 365,
#  'makasih': 366,
#  'pasti': 367,
#  'controller': 368,
#  'asik': 369,
#  'rating': 370,
#  'geme': 371,
#  'overall': 372,
#  'kedepannya': 373,
#  '8': 374,
#  'mainkan': 375,
#  'menurut': 376,
#  'full': 377,
#  'gimana': 378,
#  'males': 379,
#  'bet': 380,
#  'mudah': 381,
#  'tambahkan': 382,
#  '4no': 383,
#  '🗿': 384,
#  'tinggi': 385,
#  'beri': 386,
#  'spiral': 387,
#  'hampir': 388,
#  'menang': 389,
#  'star': 390,
#  'frame': 391,
#  'semuanya': 392,
#  'cocok': 393,
#  'cepat': 394,
#  'farming': 395,
#  'petualangan': 396,
#  'bosan': 397,
#  'fps': 398,
#  'pihak': 399,
#  'ngasih': 400,
#  'burik': 401,
#  'waifu': 402,
#  'datanya': 403,
#  'abis': 404,
#  'nanti': 405,
#  'amat': 406,
#  'if': 407,
#  'low': 408,
#  'tetapi': 409,
#  'anime': 410,
#  'dll': 411,
#  'because': 412,
#  'penuh': 413,
#  'luar': 414,
#  'cara': 415,
#  'panas': 416,
#  'jelas': 417,
#  'lawan': 418,
#  'or': 419,
#  'minimal': 420,
#  'memuaskan': 421,
#  'apakah': 422,
#  'really': 423,
#  'tao': 424,
#  'hoki': 425,
#  'nunggu': 426,
#  'dev': 427,
#  'minta': 428,
#  'dunia': 429,
#  'be': 430,
#  'happy': 431,
#  'mending': 432,
#  'storage': 433,
#  'beberapa': 434,
#  'permainan': 435,
#  'benar': 436,
#  'pertama': 437,
#  'hoyovers': 438,
#  'gratis': 439,
#  'venti': 440,
#  'wifi': 441,
#  'aj': 442,
#  'sebelumnya': 443,
#  'storynya': 444,
#  'wow': 445,
#  'spek': 446,
#  'lite': 447,
#  'atas': 448,
#  'are': 449,
#  'karakternya': 450,
#  'close': 451,
#  'tetep': 452,
#  'gim': 453,
#  'semenjak': 454,
#  'kebanyakan': 455,
#  'will': 456,
#  'kata': 457,
#  'habis': 458,
#  'nge': 459,
#  'trus': 460,
#  'bulan': 461,
#  'def': 462,
#  'thanks': 463,
#  'memory': 464,
#  'why': 465,
#  'gini': 466,
#  'perlu': 467,
#  'force': 468,
#  'just': 469,
#  'kami': 470,
#  'tuh': 471,
#  'jika': 472,
#  'sampah': 473,
#  'aplikasi': 474,
#  'plis': 475,
#  'jg': 476,
#  'memang': 477,
#  'dikasih': 478,
#  'free': 479,
#  'akhirnya': 480,
#  'level': 481,
#  'enak': 482,
#  'buruk': 483,
#  'gachanya': 484,
#  'its': 485,
#  'gara': 486,
#  'nyari': 487,
#  'konten': 488,
#  'hilang': 489,
#  'puzzle': 490,
#  'bahkan': 491,
#  'tombol': 492,
#  'knp': 493,
#  'selesai': 494,
#  'even': 495,
#  'mainnya': 496,
#  'rendah': 497,
#  '100': 498,
#  'berharap': 499,
#  'berikan': 500,
#  'ngotak': 501,
#  'wajib': 502,
#  'bilang': 503,
#  'membosankan': 504,
#  'primogems': 505,
#  'merah': 506,
#  'trs': 507,
#  'namun': 508,
#  'kecil': 509,
#  'liat': 510,
#  'hehe': 511,
#  "it's": 512,
#  'beli': 513,
#  'soal': 514,
#  'perfect': 515,
#  'weapon': 516,
#  'archon': 517,
#  'harap': 518,
#  'aman': 519,
#  'banyakin': 520,
#  'want': 521,
#  'pull': 522,
#  'dimainkan': 523,
#  'adventure': 524,
#  'emang': 525,
#  'dri': 526,
#  'ringan': 527,
#  'bang': 528,
#  'pensi': 529,
#  'damage': 530,
#  'kepada': 531,
#  'there': 532,
#  'anj': 533,
#  'meledak': 534,
#  'arte': 535,
#  'rata': 536,
#  'ajg': 537,
#  'patch': 538,
#  '7': 539,
#  'mata': 540,
#  '6': 541,
#  'segera': 542,
#  'mati': 543,
#  'jauh': 544,
#  'sekian': 545,
#  'salah': 546,
#  'gila': 547,
#  'luas': 548,
#  'menunggu': 549,
#  'apk': 550,
#  'bansos': 551,
#  'hero': 552,
#  'account': 553,
#  "i'm": 554,
#  'ko': 555,
#  'permudah': 556,
#  'sesuai': 557,
#  'ngak': 558,
#  'indonesia': 559,
#  'handphone': 560,
#  'get': 561,
#  '200': 562,
#  'next': 563,
#  'gabisa': 564,
#  'all': 565,
#  'terbaru': 566,
#  'bgus': 567,
#  'lalu': 568,
#  'rilis': 569,
#  'raiden': 570,
#  "don't": 571,
#  'item': 572,
#  '16': 573,
#  'cari': 574,
#  'bakal': 575,
#  'tiap': 576,
#  'terutama': 577,
#  'desain': 578,
#  'teman': 579,
#  'wangi': 580,
#  'ah': 581,
#  'need': 582,
#  'naik': 583,
#  'cyno': 584,
#  'indah': 585,
#  'buka': 586,
#  'pengguna': 587,
#  'begitu': 588,
#  'one': 589,
#  'ganti': 590,
#  'moga': 591,
#  'eh': 592,
#  'hack': 593,
#  'bismillah': 594,
#  'as': 595,
#  'bad': 596,
#  'jalan': 597,
#  'telah': 598,
#  'op': 599,
#  'chara': 600,
#  'honkai': 601,
#  'too': 602,
#  'sehingga': 603,
#  'cool': 604,
#  'mengecewakan': 605,
#  'akhir': 606,
#  'ilang': 607,
#  'u': 608,
#  'we': 609,
#  'kuota': 610,
#  'jgn': 611,
#  'terjadi': 612,
#  'time': 613,
#  '20': 614,
#  'monster': 615,
#  'bngt': 616,
#  'pengalaman': 617,
#  'ngga': 618,
#  'mengalami': 619,
#  'kazuha': 620,
#  'spin': 621,
#  'ditambah': 622,
#  'memainkan': 623,
#  'great': 624,
#  'paimon': 625,
#  'sia': 626,
#  'menggunakan': 627,
#  'nyesel': 628,
#  'kagak': 629,
#  'render': 630,
#  'hoyo': 631,
#  'memakan': 632,
#  'keqing': 633,
#  'naikin': 634,
#  'merasakan': 635,
#  'elit': 636,
#  'muncul': 637,
#  'perbanyak': 638,
#  'endgame': 639,
#  'add': 640,
#  'aneh': 641,
#  'sukses': 642,
#  'still': 643,
#  'again': 644,
#  'melihat': 645,
#  'kembali': 646,
#  'bgs': 647,
#  'xiao': 648,
#  'sebelum': 649,
#  "story'": 650,
#  'boleh': 651,
#  'ganyu': 652,
#  'sedang': 653,
#  'when': 654,
#  'katanya': 655,
#  'dlu': 656,
#  'tunggu': 657,
#  'forno': 658,
#  '🥰': 659,
#  'musik': 660,
#  'nilou': 661,
#  'lima': 662,
#  'loh': 663,
#  'inazuma': 664,
#  'sebagai': 665,
#  'babi': 666,
#  'sebenarnya': 667,
#  'thank': 668,
#  '😁': 669,
#  'error': 670,
#  'memanjakan': 671,
#  'lupa': 672,
#  'aniv': 673,
#  'oh': 674,
#  'tempat': 675,
#  'setting': 676,
#  'wah': 677,
#  'kurangin': 678,
#  'snapdragon': 679,
#  'stabil': 680,
#  'jdi': 681,
#  'tingkatkan': 682,
#  'ternyata': 683,
#  'pokonya': 684,
#  'lg': 685,
#  'seruu': 686,
#  'kurangi': 687,
#  'meskipun': 688,
#  '15': 689,
#  'animasi': 690,
#  'memiliki': 691,
#  'puas': 692,
#  'boss': 693,
#  'upgrade': 694,
#  '90': 695,
#  'ruang': 696,
#  'from': 697,
#  'pusing': 698,
#  'makan': 699,
#  'pokok': 700,
#  'y': 701,
#  'capek': 702,
#  '9': 703,
#  'bingung': 704,
#  'material': 705,
#  'nerf': 706,
#  'hope': 707,
#  'bantu': 708,
#  'abyss': 709,
#  'penting': 710,
#  'phone': 711,
#  'yae': 712,
#  'iya': 713,
#  'pula': 714,
#  'better': 715,
#  'log': 716,
#  'jam': 717,
#  'win': 718,
#  'ayaka': 719,
#  'kapan': 720,
#  'amazing': 721,
#  'optimalkan': 722,
#  'berhenti': 723,
#  'sedih': 724,
#  'usah': 725,
#  'kena': 726,
#  'menengah': 727,
#  'gaming': 728,
#  'rame': 729,
#  'asia': 730,
#  't': 731,
#  'file': 732,
#  'ayo': 733,
#  'some': 734,
#  'yoimiya': 735,
#  'enjoy': 736,
#  'bnyk': 737,
#  "can't": 738,
#  'graphic': 739,
#  'gensin': 740,
#  'selain': 741,
#  'berpetualang': 742,
#  'dh': 743,
#  'after': 744,
#  'suruh': 745,
#  'tersebut': 746,
#  'always': 747,
#  'rerun': 748,
#  'sempurna': 749,
#  'temen': 750,
#  'gud': 751,
#  'malas': 752,
#  'balik': 753,
#  'teka': 754,
#  'teki': 755,
#  'mendukung': 756,
#  'santai': 757,
#  'sayangnya': 758,
#  'ngeframe': 759,
#  'koneksi': 760,
#  'wish': 761,
#  'selama': 762,
#  'much': 763,
#  'fun': 764,
#  'emosi': 765,
#  'jumlah': 766,
#  'kesini': 767,
#  'b': 768,
#  'tdk': 769,
#  'cmn': 770,
#  'dialog': 771,
#  'secara': 772,
#  'pindah': 773,
#  '30': 774,
#  'fantasy': 775,
#  'your': 776,
#  'anjir': 777,
#  'now': 778,
#  'kaga': 779,
#  'rng': 780,
#  'uninstall': 781,
#  'ampe': 782,
#  'internet': 783,
#  'yaitu': 784,
#  'memberikan': 785,
#  'intinya': 786,
#  'tentang': 787,
#  'hati': 788,
#  'memo': 789,
#  '2nd': 790,
#  'ghensin': 791,
#  'lgi': 792,
#  'pemandangan': 793,
#  'duit': 794,
#  'pliss': 795,
#  'pemula': 796,
#  'content': 797,
#  'mmorpg': 798,
#  'rank': 799,
#  'new': 800,
#  'abys': 801,
#  'kuning': 802,
#  'miko': 803,
#  '4gb': 804,
#  'sini': 805,
#  'gamepad': 806,
#  'yaa': 807,
#  '128': 808,
#  'ad': 809,
#  'pengaturan': 810,
#  'wkwk': 811,
#  'cepet': 812,
#  'eror': 813,
#  'kendala': 814,
#  '🙏': 815,
#  'tolol': 816,
#  'turunin': 817,
#  'bagian': 818,
#  'keseluruhan': 819,
#  'mencari': 820,
#  'jujur': 821,
#  'hutao': 822,
#  'btw': 823,
#  'mantab': 824,
#  'mayan': 825,
#  'benerin': 826,
#  'install': 827,
#  'nyoba': 828,
#  'spam': 829,
#  'tu': 830,
#  '70': 831,
#  'tower': 832,
#  'sya': 833,
#  'playing': 834,
#  'berkembang': 835,
#  'dear': 836,
#  'tambahan': 837,
#  'at': 838,
#  '🙂': 839,
#  'rusak': 840,
#  'mona': 841,
#  'bawah': 842,
#  'smartphone': 843,
#  'sekitar': 844,
#  'updatenya': 845,
#  'traveler': 846,
#  'ngulang': 847,
#  'maupun': 848,
#  'favorit': 849,
#  'dimainin': 850,
#  'suara': 851,
#  'anniv': 852,
#  'senang': 853,
#  'guna': 854,
#  'job': 855,
#  'sizenya': 856,
#  'uang': 857,
#  'lainnya': 858,
#  'hadeh': 859,
#  'do': 860,
#  'turun': 861,
#  'beda': 862,
#  'cutscene': 863,
#  '8gb': 864,
#  'mabar': 865,
#  'terbatas': 866,
#  '🥲': 867,
#  'gi': 868,
#  'dimana': 869,
#  '60': 870,
#  'poco': 871,
#  'gratisan': 872,
#  'memukau': 873,
#  'co': 874,
#  "i've": 875,
#  'optimal': 876,
#  'gagal': 877,
#  'crit': 878,
#  'mahal': 879,
#  'kekurangan': 880,
#  'menyukai': 881,
#  'ak': 882,
#  'tanpa': 883,
#  'sakit': 884,
#  'gabut': 885,
#  'go': 886,
#  'characters': 887,
#  'dua': 888,
#  'user': 889,
#  'bs': 890,
#  'ngabisin': 891,
#  'dr': 892,
#  'ditambahkan': 893,
#  'rasa': 894,
#  'giliran': 895,
#  'back': 896,
#  '14': 897,
#  'kanan': 898,
#  'rekomendasi': 899,
#  'ygy': 900,
#  'medium': 901,
#  'kapasitas': 902,
#  'explore': 903,
#  'far': 904,
#  'bos': 905,
#  '😭': 906,
#  'pvp': 907,
#  'skrg': 908,
#  'hijau': 909,
#  'cape': 910,
#  'pay': 911,
#  'stat': 912,
#  'w': 913,
#  'kokomi': 914,
#  'lbh': 915,
#  'yh': 916,
#  'jd': 917,
#  'memainkannya': 918,
#  'apaan': 919,
#  'tinggal': 920,
#  'diatas': 921,
#  '18gb': 922,
#  'jarang': 923,
#  'gampang': 924,
#  'selanjutnya': 925,
#  'hidup': 926,
#  'gpp': 927,
#  'aniversary': 928,
#  'shogun': 929,
#  'also': 930,
#  'youtube': 931,
#  'toxic': 932,
#  'ap': 933,
#  'kebawah': 934,
#  'tolonglah': 935,
#  'berapa': 936,
#  'change': 937,
#  'bangett': 938,
#  'sabar': 939,
#  'eventnya': 940,
#  'played': 941,
#  'dapetin': 942,
#  'storyline': 943,
#  'daily': 944,
#  'build': 945,
#  'cakep': 946,
#  'menikmati': 947,
#  'tof': 948,
#  'graphics': 949,
#  'artifact': 950,
#  'menit': 951,
#  'her': 952,
#  'dowload': 953,
#  'lo': 954,
#  'text': 955,
#  'hape': 956,
#  'tak': 957,
#  'kamu': 958,
#  'disuruh': 959,
#  'sungguh': 960,
#  'n': 961,
#  'otak': 962,
#  'games': 963,
#  'mampu': 964,
#  '❤️': 965,
#  'kecilin': 966,
#  'cantik': 967,
#  'ambil': 968,
#  'akal': 969,
#  'version': 970,
#  'ngumpulin': 971,
#  'rumput': 972,
#  'skill': 973,
#  'stuck': 974,
#  'jean': 975,
#  'nambah': 976,
#  'perkecil': 977,
#  'was': 978,
#  'musuhnya': 979,
#  'anjay': 980,
#  'mengapa': 981,
#  'tahu': 982,
#  'biasanya': 983,
#  'j2': 984,
#  'prime': 985,
#  'come': 986,
#  'instal': 987,
#  'donlod': 988,
#  '16gb': 989,
#  'muat': 990,
#  'sebelah': 991,
#  'normal': 992,
#  'out': 993,
#  '160': 994,
#  'utk': 995,
#  'set': 996,
#  'sejak': 997,
#  'tanah': 998,
#  'music': 999,
#  'merasa': 1000,
#  ...}

# %%
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences, maxlen=max_length, truncating=trunc_type)
testing_sentences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sentences, maxlen=max_length)
# Out:
# Downloading:   1%|          | 2.77M/536M [10:09:39<1957:43:52, 75.7B/s]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim,       input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 120, 16)           640000
#
#  global_average_pooling1d_2   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 6)                 102
#
#  dense_5 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 640,109
# Trainable params: 640,109
# Non-trainable params: 0
# _________________________________________________________________

# %%
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)

testing_labels_final
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
num_epochs = 20
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/20
# 225/225 [==============================] - 3s 11ms/step - loss: 0.5457 - accuracy: 0.8206 - val_loss: 0.4685 - val_accuracy: 0.8169
# Epoch 2/20
# 225/225 [==============================] - 2s 10ms/step - loss: 0.4608 - accuracy: 0.8206 - val_loss: 0.4652 - val_accuracy: 0.8169
# Epoch 3/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.4571 - accuracy: 0.8206 - val_loss: 0.4624 - val_accuracy: 0.8169
# Epoch 4/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.4535 - accuracy: 0.8206 - val_loss: 0.4586 - val_accuracy: 0.8169
# Epoch 5/20
# 225/225 [==============================] - 2s 8ms/step - loss: 0.4489 - accuracy: 0.8206 - val_loss: 0.4547 - val_accuracy: 0.8169
# Epoch 6/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.4407 - accuracy: 0.8214 - val_loss: 0.4444 - val_accuracy: 0.8175
# Epoch 7/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.4250 - accuracy: 0.8246 - val_loss: 0.4294 - val_accuracy: 0.8196
# Epoch 8/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.4026 - accuracy: 0.8286 - val_loss: 0.4105 - val_accuracy: 0.8231
# Epoch 9/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.3763 - accuracy: 0.8364 - val_loss: 0.3951 - val_accuracy: 0.8252
# Epoch 10/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.3504 - accuracy: 0.8446 - val_loss: 0.3764 - val_accuracy: 0.8288
# Epoch 11/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.3249 - accuracy: 0.8562 - val_loss: 0.3640 - val_accuracy: 0.8317
# Epoch 12/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.3033 - accuracy: 0.8651 - val_loss: 0.3546 - val_accuracy: 0.8402
# Epoch 13/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2846 - accuracy: 0.8765 - val_loss: 0.3506 - val_accuracy: 0.8485
# Epoch 14/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2684 - accuracy: 0.8835 - val_loss: 0.3439 - val_accuracy: 0.8454
# Epoch 15/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2537 - accuracy: 0.8899 - val_loss: 0.3414 - val_accuracy: 0.8521
# Epoch 16/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2401 - accuracy: 0.8953 - val_loss: 0.3396 - val_accuracy: 0.8523
# Epoch 17/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2279 - accuracy: 0.9008 - val_loss: 0.3395 - val_accuracy: 0.8529
# Epoch 18/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2166 - accuracy: 0.9064 - val_loss: 0.3421 - val_accuracy: 0.8548
# Epoch 19/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2080 - accuracy: 0.9133 - val_loss: 0.3419 - val_accuracy: 0.8548
# Epoch 20/20
# 225/225 [==============================] - 2s 9ms/step - loss: 0.1978 - accuracy: 0.9211 - val_loss: 0.3487 - val_accuracy: 0.8537

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs=range(len(acc))
plt.plot(epochs, acc, 'r', 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', 'Validation Accuracy')
plt.title('Training and validation accuracy')
plt.figure()
plt.plot(epochs, loss, 'r', 'Training Loss')
plt.plot(epochs, val_loss, 'b', 'Validation Loss')
plt.title('Training and validation loss')
plt.figure()

# %%
predict_sentences = tokenizer.texts_to_sequences([
"Eh Hasilnya AMPAS!!!",
"Semakin mantep Update Sumeru. Semua dari update ini saya Suka Semua dari segi Design Charnya, Viewnya, Dan juga Story nya Epic PARAAHHH",
"jelek banget",
"bagus"])
predict_padded = pad_sequences(predict_sentences, maxlen=max_length)

model.predict(predict_padded)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([[0.62189   ],
#        [0.98525274],
#        [0.48760584],
#        [0.960115  ]], dtype=float32)
